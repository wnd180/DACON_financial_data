# %%
import pandas as pd
from pandas import DataFrame
from pandas import Series
import numpy as np
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:.5f}'.format
pd.options.display.float_format = '{:,.0f}'.format

df = pd.read_csv("2016-2020_연도_최종예산_정리본.csv")
df = df[["소관", "회계", "분야", "부문", "프로그램", "단위사업", "세부사업", "연도", "최종예산"]]
df
# Out:
# RangeIndex(start=0, stop=1854, step=1)

# %%
#연도별 예산순위

val1 = input("소관 입력")

is_val1 = df["소관"] == val1
df1 = df[is_val1]
df1

val2 = int(input("연도 입력"))
is_val2 = df["연도"] == val2
df2 = df[is_val2]
df2
# Out:
#        소관             회계       분야     부문            프로그램           단위사업  \
# 1441  환경부           일반회계    교통및물류  물류등기타          건설정책지원      해외인프라시장개혁
# 1442  환경부       금강수계관리기금       환경    물환경         4대강유역관리     환경기초시설(금강)
# 1443  환경부           일반회계  국토및지역개발    수자원  댐건설 및 댐치수능력 증대          댐운영지원
# 1444  환경부       금강수계관리기금       환경    물환경         4대강유역관리     주민지원사업(금강)
# 1445  환경부       금강수계관리기금       환경    물환경         4대강유역관리     환경기초시설(금강)
# ...   ...            ...      ...    ...             ...            ...
# 1849  환경부       환경개선특별회계       환경   환경일반         환경행정 지원          환경정보화
# 1850  환경부       환경개선특별회계       환경   환경일반      회계간거래(전출금)          회계간전출
# 1851  환경부       환경개선특별회계       환경    물환경       맑은물 공급・이용  물재이용 및 물기술 개발
# 1852  환경부       환경개선특별회계       환경    물환경         물오염원 관리         하수도 관리
# 1853  환경부  영산강・섬진강수계관리기금       환경    물환경         4대강유역관리  기타수질개선지원(영산강)
#
#                           세부사업    연도           최종예산
# 1441          국제개발협력사업 지원(ODA)  2020  5,950,000,000
# 1442                  환경기초시설운영  2020 22,146,000,000
# 1443           댐 안전성강화(Ⅰ단계) 사업  2020 52,101,000,000
# 1444             주민지원사업평가및DB지원  2020    574,000,000
# 1445                 환경기초시설 설치  2020 33,863,000,000
# ...                        ...   ...            ...
# 1849   환경정보 융합빅데이터 플랫폼 구축(정보화)  2020  1,278,000,000
# 1850  국가균형발전특별회계(제주특별자치도계정) 전출  2020 13,442,000,000
# 1851                물산업클러스터 운영  2020 18,040,000,000
# 1852            노후하수관로 정밀조사 지원  2020 15,879,000,000
# 1853                 비점오염 저감사업  2020  1,156,000,000
#
# [413 rows x 9 columns]
